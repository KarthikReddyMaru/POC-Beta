# %%
import requests
from os import getenv
from dotenv import load_dotenv
from json import loads, dumps
from IPython.display import display, Markdown
from pprint import pprint

# %%
load_dotenv(override = True)

GITHUB_ACCESS_TOKEN = getenv('GITHUB_ACCESS_TOKEN')

if not GITHUB_ACCESS_TOKEN:
    print('No Token found')

# %%
from pydantic import BaseModel, Field, TypeAdapter

class Change(BaseModel):
    file_name: str
    status: str = Field(description = "Added/Modified/Deleted")
    patch: str = Field(description = "Changes made")

class Progress(BaseModel):
    task_summary: str = Field(description = "Title of task")
    recent_activity: list[str] = Field(description = "List of commit messages")
    changes: list[Change]

# %%
BASE_URI = "https://api.github.com"
COMPARE_PATH = "/repos/{owner}/{repository}/compare/{base_branch}...{feature_branch}"

# %%
owner = 'KarthikReddyMaru'
repository = 'test'
base_branch = 'main'
feature_branch = 'feat/ryomen'

URI = BASE_URI + COMPARE_PATH.format(
    owner = owner, 
    repository = repository, 
    base_branch = base_branch,
    feature_branch = feature_branch
)

headers = {
    'Authorization': f"Bearer {GITHUB_ACCESS_TOKEN}"
}

response = requests.get(url = URI, headers = headers)

# %%
content = loads(response.content)
content
# Out:
# {'url': 'https://api.github.com/repos/KarthikReddyMaru/test/compare/main...feat/ryomen',
#  'html_url': 'https://github.com/KarthikReddyMaru/test/compare/main...feat/ryomen',
#  'permalink_url': 'https://github.com/KarthikReddyMaru/test/compare/KarthikReddyMaru:54597d4...KarthikReddyMaru:67bb213',
#  'diff_url': 'https://github.com/KarthikReddyMaru/test/compare/main...feat/ryomen.diff',
#  'patch_url': 'https://github.com/KarthikReddyMaru/test/compare/main...feat/ryomen.patch',
#  'base_commit': {'sha': '54597d4426a89bc8f7796d10a8a287467361105a',
#   'node_id': 'C_kwDOQyV8ltoAKDU0NTk3ZDQ0MjZhODliYzhmNzc5NmQxMGE4YTI4NzQ2NzM2MTEwNWE',
#   'commit': {'author': {'name': 'Maru Karthik Reddy',
#     'email': 'karthikreddy.maru@gmail.com',
#     'date': '2026-01-02T05:19:26Z'},
#    'committer': {'name': 'Maru Karthik Reddy',
#     'email': 'karthikreddy.maru@gmail.com',
#     'date': '2026-01-02T05:19:26Z'},
#    'message': 'add food items',
#    'tree': {'sha': '6f31b194e4ddb9b5f478490bc7ae7333ea8164ec',
#     'url': 'https://api.github.com/repos/KarthikReddyMaru/test/git/trees/6f31b194e4ddb9b5f478490bc7ae7333ea8164ec'},
#    'url': 'https://api.github.com/repos/KarthikReddyMaru/test/git/commits/54597d4426a89bc8f7796d10a8a287467361105a',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN SSH SIGNATURE-----\nU1NIU0lHAAAAAQAAADMAAAALc3NoLWVkMjU1MTkAAAAgBgryK9tj9zrPwhbfNcd0xxC4AS\nHuW+/s67sfxVu0GtAAAAADZ2l0AAAAAAAAAAZzaGE1MTIAAABTAAAAC3NzaC1lZDI1NTE5\nAAAAQBY3/cE3QA72m9kGAwIzjTxq3q4n17VRKEagbhM4e5siCmFpnGAOcEChT1ctsL9HHD\nUiXSzu/XDdjVMk7eJs1A4=\n-----END SSH SIGNATURE-----',
#     'payload': 'tree 6f31b194e4ddb9b5f478490bc7ae7333ea8164ec\nparent a65b0eb4b1689cfdb55c0d77d2add10c85a1f177\nauthor Maru Karthik Reddy <karthikreddy.maru@gmail.com> 1767331166 +0530\ncommitter Maru Karthik Reddy <karthikreddy.maru@gmail.com> 1767331166 +0530\n\nadd food items\n',
#     'verified_at': '2026-01-02T05:20:42Z'}},
#   'url': 'https://api.github.com/repos/KarthikReddyMaru/test/commits/54597d4426a89bc8f7796d10a8a287467361105a',
#   'html_url': 'https://github.com/KarthikReddyMaru/test/commit/54597d4426a89bc8f7796d10a8a287467361105a',
#   'comments_url': 'https://api.github.com/repos/KarthikReddyMaru/test/commits/54597d4426a89bc8f7796d10a8a287467361105a/comments',
#   'author': {'login': 'KarthikReddyMaru',
#    'id': 96712386,
#    'node_id': 'U_kgDOBcO2wg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96712386?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/KarthikReddyMaru',
#    'html_url': 'https://github.com/KarthikReddyMaru',
#    'followers_url': 'https://api.github.com/users/KarthikReddyMaru/followers',
#    'following_url': 'https://api.github.com/users/KarthikReddyMaru/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/KarthikReddyMaru/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/KarthikReddyMaru/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/KarthikReddyMaru/subscriptions',
#    'organizations_url': 'https://api.github.com/users/KarthikReddyMaru/orgs',
#    'repos_url': 'https://api.github.com/users/KarthikReddyMaru/repos',
#    'events_url': 'https://api.github.com/users/KarthikReddyMaru/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/KarthikReddyMaru/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'KarthikReddyMaru',
#    'id': 96712386,
#    'node_id': 'U_kgDOBcO2wg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96712386?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/KarthikReddyMaru',
#    'html_url': 'https://github.com/KarthikReddyMaru',
#    'followers_url': 'https://api.github.com/users/KarthikReddyMaru/followers',
#    'following_url': 'https://api.github.com/users/KarthikReddyMaru/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/KarthikReddyMaru/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/KarthikReddyMaru/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/KarthikReddyMaru/subscriptions',
#    'organizations_url': 'https://api.github.com/users/KarthikReddyMaru/orgs',
#    'repos_url': 'https://api.github.com/users/KarthikReddyMaru/repos',
#    'events_url': 'https://api.github.com/users/KarthikReddyMaru/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/KarthikReddyMaru/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': 'a65b0eb4b1689cfdb55c0d77d2add10c85a1f177',
#     'url': 'https://api.github.com/repos/KarthikReddyMaru/test/commits/a65b0eb4b1689cfdb55c0d77d2add10c85a1f177',
#     'html_url': 'https://github.com/KarthikReddyMaru/test/commit/a65b0eb4b1689cfdb55c0d77d2add10c85a1f177'}]},
#  'merge_base_commit': {'sha': '004f9a5c2be2ef3be1f37c2ac9510a6353606caa',
#   'node_id': 'C_kwDOQyV8ltoAKDAwNGY5YTVjMmJlMmVmM2JlMWYzN2MyYWM5NTEwYTYzNTM2MDZjYWE',
#   'commit': {'author': {'name': 'Maru Karthik Reddy',
#     'email': 'karthikreddy.maru@gmail.com',
#     'date': '2026-01-02T05:13:40Z'},
#    'committer': {'name': 'Maru Karthik Reddy',
#     'email': 'karthikreddy.maru@gmail.com',
#     'date': '2026-01-02T05:13:40Z'},
#    'message': 'feat(song): add songs.txt',
#    'tree': {'sha': '72af2c9ea58ca808ebb5711fdcc3acb558583f62',
#     'url': 'https://api.github.com/repos/KarthikReddyMaru/test/git/trees/72af2c9ea58ca808ebb5711fdcc3acb558583f62'},
#    'url': 'https://api.github.com/repos/KarthikReddyMaru/test/git/commits/004f9a5c2be2ef3be1f37c2ac9510a6353606caa',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN SSH SIGNATURE-----\nU1NIU0lHAAAAAQAAADMAAAALc3NoLWVkMjU1MTkAAAAgBgryK9tj9zrPwhbfNcd0xxC4AS\nHuW+/s67sfxVu0GtAAAAADZ2l0AAAAAAAAAAZzaGE1MTIAAABTAAAAC3NzaC1lZDI1NTE5\nAAAAQOyy9T+CL9RC4RvPG2KWA2xu13k9PwgyovbYd/K9m9Evv1bUoJ3hfzq4WK/SoKf2am\nkie6RAsEgHMJU1ZkQ25Qk=\n-----END SSH SIGNATURE-----',
#     'payload': 'tree 72af2c9ea58ca808ebb5711fdcc3acb558583f62\nparent bc63f29fdd79f54fb2c18bab6354385b11e98bab\nauthor Maru Karthik Reddy <karthikreddy.maru@gmail.com> 1767330820 +0530\ncommitter Maru Karthik Reddy <karthikreddy.maru@gmail.com> 1767330820 +0530\n\nfeat(song): add songs.txt\n',
#     'verified_at': '2026-01-02T05:15:56Z'}},
#   'url': 'https://api.github.com/repos/KarthikReddyMaru/test/commits/004f9a5c2be2ef3be1f37c2ac9510a6353606caa',
#   'html_url': 'https://github.com/KarthikReddyMaru/test/commit/004f9a5c2be2ef3be1f37c2ac9510a6353606caa',
#   'comments_url': 'https://api.github.com/repos/KarthikReddyMaru/test/commits/004f9a5c2be2ef3be1f37c2ac9510a6353606caa/comments',
#   'author': {'login': 'KarthikReddyMaru',
#    'id': 96712386,
#    'node_id': 'U_kgDOBcO2wg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96712386?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/KarthikReddyMaru',
#    'html_url': 'https://github.com/KarthikReddyMaru',
#    'followers_url': 'https://api.github.com/users/KarthikReddyMaru/followers',
#    'following_url': 'https://api.github.com/users/KarthikReddyMaru/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/KarthikReddyMaru/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/KarthikReddyMaru/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/KarthikReddyMaru/subscriptions',
#    'organizations_url': 'https://api.github.com/users/KarthikReddyMaru/orgs',
#    'repos_url': 'https://api.github.com/users/KarthikReddyMaru/repos',
#    'events_url': 'https://api.github.com/users/KarthikReddyMaru/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/KarthikReddyMaru/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'KarthikReddyMaru',
#    'id': 96712386,
#    'node_id': 'U_kgDOBcO2wg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96712386?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/KarthikReddyMaru',
#    'html_url': 'https://github.com/KarthikReddyMaru',
#    'followers_url': 'https://api.github.com/users/KarthikReddyMaru/followers',
#    'following_url': 'https://api.github.com/users/KarthikReddyMaru/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/KarthikReddyMaru/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/KarthikReddyMaru/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/KarthikReddyMaru/subscriptions',
#    'organizations_url': 'https://api.github.com/users/KarthikReddyMaru/orgs',
#    'repos_url': 'https://api.github.com/users/KarthikReddyMaru/repos',
#    'events_url': 'https://api.github.com/users/KarthikReddyMaru/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/KarthikReddyMaru/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': 'bc63f29fdd79f54fb2c18bab6354385b11e98bab',
#     'url': 'https://api.github.com/repos/KarthikReddyMaru/test/commits/bc63f29fdd79f54fb2c18bab6354385b11e98bab',
#     'html_url': 'https://github.com/KarthikReddyMaru/test/commit/bc63f29fdd79f54fb2c18bab6354385b11e98bab'}]},
#  'status': 'diverged',
#  'ahead_by': 2,
#  'behind_by': 2,
#  'total_commits': 2,
#  'commits': [{'sha': 'cb05a10ccef86ef7d81938fea74bacda885b0b0f',
#    'node_id': 'C_kwDOQyV8ltoAKGNiMDVhMTBjY2VmODZlZjdkODE5MzhmZWE3NGJhY2RhODg1YjBiMGY',
#    'commit': {'author': {'name': 'Maru Karthik Reddy',
#      'email': 'karthikreddy.maru@gmail.com',
#      'date': '2026-01-02T05:15:45Z'},
#     'committer': {'name': 'Maru Karthik Reddy',
#      'email': 'karthikreddy.maru@gmail.com',
#      'date': '2026-01-02T05:15:45Z'},
#     'message': 'feat(songs): add few songs',
#     'tree': {'sha': 'adad38d5a3343c44a5b55c3d22ce749655c8cf62',
#      'url': 'https://api.github.com/repos/KarthikReddyMaru/test/git/trees/adad38d5a3343c44a5b55c3d22ce749655c8cf62'},
#     'url': 'https://api.github.com/repos/KarthikReddyMaru/test/git/commits/cb05a10ccef86ef7d81938fea74bacda885b0b0f',
#     'comment_count': 0,
#     'verification': {'verified': True,
#      'reason': 'valid',
#      'signature': '-----BEGIN SSH SIGNATURE-----\nU1NIU0lHAAAAAQAAADMAAAALc3NoLWVkMjU1MTkAAAAgBgryK9tj9zrPwhbfNcd0xxC4AS\nHuW+/s67sfxVu0GtAAAAADZ2l0AAAAAAAAAAZzaGE1MTIAAABTAAAAC3NzaC1lZDI1NTE5\nAAAAQB+YKbiwMr8HfrMcdEWjmFZiSUCGNGhD1K9gxM6DWQXzSmV1umKqgonu6iGtuOdGPL\n5NFovzrL5OO7gGJBz/FAU=\n-----END SSH SIGNATURE-----',
#      'payload': 'tree adad38d5a3343c44a5b55c3d22ce749655c8cf62\nparent 004f9a5c2be2ef3be1f37c2ac9510a6353606caa\nauthor Maru Karthik Reddy <karthikreddy.maru@gmail.com> 1767330945 +0530\ncommitter Maru Karthik Reddy <karthikreddy.maru@gmail.com> 1767330945 +0530\n\nfeat(songs): add few songs\n',
#      'verified_at': '2026-01-02T05:15:56Z'}},
#    'url': 'https://api.github.com/repos/KarthikReddyMaru/test/commits/cb05a10ccef86ef7d81938fea74bacda885b0b0f',
#    'html_url': 'https://github.com/KarthikReddyMaru/test/commit/cb05a10ccef86ef7d81938fea74bacda885b0b0f',
#    'comments_url': 'https://api.github.com/repos/KarthikReddyMaru/test/commits/cb05a10ccef86ef7d81938fea74bacda885b0b0f/comments',
#    'author': {'login': 'KarthikReddyMaru',
#     'id': 96712386,
#     'node_id': 'U_kgDOBcO2wg',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/96712386?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/KarthikReddyMaru',
#     'html_url': 'https://github.com/KarthikReddyMaru',
#     'followers_url': 'https://api.github.com/users/KarthikReddyMaru/followers',
#     'following_url': 'https://api.github.com/users/KarthikReddyMaru/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/KarthikReddyMaru/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/KarthikReddyMaru/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/KarthikReddyMaru/subscriptions',
#     'organizations_url': 'https://api.github.com/users/KarthikReddyMaru/orgs',
#     'repos_url': 'https://api.github.com/users/KarthikReddyMaru/repos',
#     'events_url': 'https://api.github.com/users/KarthikReddyMaru/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/KarthikReddyMaru/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'committer': {'login': 'KarthikReddyMaru',
#     'id': 96712386,
#     'node_id': 'U_kgDOBcO2wg',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/96712386?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/KarthikReddyMaru',
#     'html_url': 'https://github.com/KarthikReddyMaru',
#     'followers_url': 'https://api.github.com/users/KarthikReddyMaru/followers',
#     'following_url': 'https://api.github.com/users/KarthikReddyMaru/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/KarthikReddyMaru/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/KarthikReddyMaru/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/KarthikReddyMaru/subscriptions',
#     'organizations_url': 'https://api.github.com/users/KarthikReddyMaru/orgs',
#     'repos_url': 'https://api.github.com/users/KarthikReddyMaru/repos',
#     'events_url': 'https://api.github.com/users/KarthikReddyMaru/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/KarthikReddyMaru/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'parents': [{'sha': '004f9a5c2be2ef3be1f37c2ac9510a6353606caa',
#      'url': 'https://api.github.com/repos/KarthikReddyMaru/test/commits/004f9a5c2be2ef3be1f37c2ac9510a6353606caa',
#      'html_url': 'https://github.com/KarthikReddyMaru/test/commit/004f9a5c2be2ef3be1f37c2ac9510a6353606caa'}]},
#   {'sha': '67bb21379c8b936a7e3ba5348a94e4acf659ae04',
#    'node_id': 'C_kwDOQyV8ltoAKDY3YmIyMTM3OWM4YjkzNmE3ZTNiYTUzNDhhOTRlNGFjZjY1OWFlMDQ',
#    'commit': {'author': {'name': 'Maru Karthik Reddy',
#      'email': 'karthikreddy.maru@gmail.com',
#      'date': '2026-01-02T05:32:17Z'},
#     'committer': {'name': 'Maru Karthik Reddy',
#      'email': 'karthikreddy.maru@gmail.com',
#      'date': '2026-01-02T05:32:17Z'},
#     'message': 'add movies.txt',
#     'tree': {'sha': 'ba410c72d4708672946fa6b5219cb03d9ea930d6',
#      'url': 'https://api.github.com/repos/KarthikReddyMaru/test/git/trees/ba410c72d4708672946fa6b5219cb03d9ea930d6'},
#     'url': 'https://api.github.com/repos/KarthikReddyMaru/test/git/commits/67bb21379c8b936a7e3ba5348a94e4acf659ae04',
#     'comment_count': 0,
#     'verification': {'verified': True,
#      'reason': 'valid',
#      'signature': '-----BEGIN SSH SIGNATURE-----\nU1NIU0lHAAAAAQAAADMAAAALc3NoLWVkMjU1MTkAAAAgBgryK9tj9zrPwhbfNcd0xxC4AS\nHuW+/s67sfxVu0GtAAAAADZ2l0AAAAAAAAAAZzaGE1MTIAAABTAAAAC3NzaC1lZDI1NTE5\nAAAAQKucXMEVaKVN5yT10MKYcsI6NgZzNkO0m1lj5mqMiiRcti+HovQr/yqxRn4iGa0oKT\nMz5fPcIMQphCVsU5mkHgg=\n-----END SSH SIGNATURE-----',
#      'payload': 'tree ba410c72d4708672946fa6b5219cb03d9ea930d6\nparent cb05a10ccef86ef7d81938fea74bacda885b0b0f\nauthor Maru Karthik Reddy <karthikreddy.maru@gmail.com> 1767331937 +0530\ncommitter Maru Karthik Reddy <karthikreddy.maru@gmail.com> 1767331937 +0530\n\nadd movies.txt\n',
#      'verified_at': '2026-01-02T05:32:25Z'}},
#    'url': 'https://api.github.com/repos/KarthikReddyMaru/test/commits/67bb21379c8b936a7e3ba5348a94e4acf659ae04',
#    'html_url': 'https://github.com/KarthikReddyMaru/test/commit/67bb21379c8b936a7e3ba5348a94e4acf659ae04',
#    'comments_url': 'https://api.github.com/repos/KarthikReddyMaru/test/commits/67bb21379c8b936a7e3ba5348a94e4acf659ae04/comments',
#    'author': {'login': 'KarthikReddyMaru',
#     'id': 96712386,
#     'node_id': 'U_kgDOBcO2wg',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/96712386?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/KarthikReddyMaru',
#     'html_url': 'https://github.com/KarthikReddyMaru',
#     'followers_url': 'https://api.github.com/users/KarthikReddyMaru/followers',
#     'following_url': 'https://api.github.com/users/KarthikReddyMaru/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/KarthikReddyMaru/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/KarthikReddyMaru/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/KarthikReddyMaru/subscriptions',
#     'organizations_url': 'https://api.github.com/users/KarthikReddyMaru/orgs',
#     'repos_url': 'https://api.github.com/users/KarthikReddyMaru/repos',
#     'events_url': 'https://api.github.com/users/KarthikReddyMaru/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/KarthikReddyMaru/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'committer': {'login': 'KarthikReddyMaru',
#     'id': 96712386,
#     'node_id': 'U_kgDOBcO2wg',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/96712386?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/KarthikReddyMaru',
#     'html_url': 'https://github.com/KarthikReddyMaru',
#     'followers_url': 'https://api.github.com/users/KarthikReddyMaru/followers',
#     'following_url': 'https://api.github.com/users/KarthikReddyMaru/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/KarthikReddyMaru/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/KarthikReddyMaru/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/KarthikReddyMaru/subscriptions',
#     'organizations_url': 'https://api.github.com/users/KarthikReddyMaru/orgs',
#     'repos_url': 'https://api.github.com/users/KarthikReddyMaru/repos',
#     'events_url': 'https://api.github.com/users/KarthikReddyMaru/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/KarthikReddyMaru/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'parents': [{'sha': 'cb05a10ccef86ef7d81938fea74bacda885b0b0f',
#      'url': 'https://api.github.com/repos/KarthikReddyMaru/test/commits/cb05a10ccef86ef7d81938fea74bacda885b0b0f',
#      'html_url': 'https://github.com/KarthikReddyMaru/test/commit/cb05a10ccef86ef7d81938fea74bacda885b0b0f'}]}],
#  'files': [{'sha': '9c56818e0c30638fe42961ee3991e383f1f6c5e8',
#    'filename': 'movies.txt',
#    'status': 'added',
#    'additions': 5,
#    'deletions': 0,
#    'changes': 5,
#    'blob_url': 'https://github.com/KarthikReddyMaru/test/blob/67bb21379c8b936a7e3ba5348a94e4acf659ae04/movies.txt',
#    'raw_url': 'https://github.com/KarthikReddyMaru/test/raw/67bb21379c8b936a7e3ba5348a94e4acf659ae04/movies.txt',
#    'contents_url': 'https://api.github.com/repos/KarthikReddyMaru/test/contents/movies.txt?ref=67bb21379c8b936a7e3ba5348a94e4acf659ae04',
#    'patch': '@@ -0,0 +1,5 @@\n+=== WEEKEND PLAN ===\n+\n+Which move should we watch this weekend?\n+\n+<!-- Suggestions here -->\n\\ No newline at end of file'},
#   {'sha': 'd63515115ac84886792b81a0889b1d2653303fe7',
#    'filename': 'songs.txt',
#    'status': 'modified',
#    'additions': 5,
#    'deletions': 1,
#    'changes': 6,
#    'blob_url': 'https://github.com/KarthikReddyMaru/test/blob/67bb21379c8b936a7e3ba5348a94e4acf659ae04/songs.txt',
#    'raw_url': 'https://github.com/KarthikReddyMaru/test/raw/67bb21379c8b936a7e3ba5348a94e4acf659ae04/songs.txt',
#    'contents_url': 'https://api.github.com/repos/KarthikReddyMaru/test/contents/songs.txt?ref=67bb21379c8b936a7e3ba5348a94e4acf659ae04',
#    'patch': '@@ -1,3 +1,7 @@\n === FIELD TRIP ===\n \n-<!-- Add songs here -->\n\\ No newline at end of file\n+<!-- Add songs here -->\n+\n+1. Hall of fame\n+2. Thunder\n+3. Till I collapse\n\\ No newline at end of file'}]}

# %%
task_summary = f"User is working on {feature_branch}"
recent_activity = [commit['commit']['message'] for commit in content['commits']]

changes = []

for change in content['files']:
    changes.append(
        Change(
            file_name = change['filename'],
            status = change['status'],
            patch = change['patch']
        )
    )

progress = Progress(task_summary = task_summary, recent_activity = recent_activity, changes = changes)

recent_activity_json = dumps(recent_activity)

changesTypeAdapter = TypeAdapter(type = list[Change])
changes_json = changesTypeAdapter.dump_python(progress.changes)

# %%
from langchain_ollama import ChatOllama
from langchain.messages import HumanMessage, SystemMessage
from langchain_core.messages import convert_to_messages

OLLAMA_MODEL = 'gpt-oss:latest'
LLM = ChatOllama(model = OLLAMA_MODEL)

# %%
SYSTEM_PROMPT = """
    You are a helpful Technical Project Manager Assistant. You have access to the realtime git development status of a project.

    **Your Goal:**
    Answer user questions about the project's progress based on the provided code changes.

    **Behavior Guidelines:**
    1. **Conversational:** If the user says "Hi" or asks a general question, reply naturally and politely. Do NOT vomit a full status report unless asked.
    2. **Context-Aware:** When the user asks about progress, status, or specific features, use the provided "Git Context" to answer accurately.
    3. **Audience-Appropriate:** Explain technical changes in simple business terms (e.g., "Added login page" instead of "Created auth.ts").
    4. **Honesty:** If the user asks something not visible in the code changes, say "I don't see evidence of that in the current changes."

    **Git Context Analysis Rules (Use these only when answering status questions):**
    - **Progress Estimation:** Scaffolding/Comments = Early Stage; Core Logic = In Progress; Tests/Edge Cases = Near Completion.
    - **Risk Detection:** Flag "TODO", "FIXME", or empty logic blocks if relevant to the user's question.
"""

# %%
USER_PROMPT = """
    ### GIT CONTEXT (Internal Data)
    Task Name: {task_summary}
    Recent Commits: {recent_activity}
    Code Changes (Diffs): {changes}

    ### USER MESSAGE
    {message}
"""

# %%
def chat(message, history):
    
    user = USER_PROMPT.format(
        task_summary = task_summary,
        recent_activity = recent_activity_json,
        changes = changes_json,
        message = message
    )
    
    # 2. Convert past history to LangChain format
    history_messages = convert_to_messages(history)
    
    # 3. Construct the full message list: System -> History -> Current User
    full_messages = [SystemMessage(content = SYSTEM_PROMPT)] + history_messages + [HumanMessage(content = user)]

    stream = LLM.stream(input = full_messages)

    response = ''
    for chunk in stream:
        response += chunk.content or ''
        yield response

# %%
import gradio as gr 

gr.ChatInterface(fn = chat).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
